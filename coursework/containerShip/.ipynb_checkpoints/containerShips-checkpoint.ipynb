# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# # Load the training data from the source CSV
# Load the dataset from the provided CSV into a numpy array and then seperate it out into the target values, training data and the ship names.

# %%
with open("containers.csv", "r") as srcF:
    src = np.array(list(csv.reader(srcF, delimiter=",")))

data = {
    "target": np.asfarray(src[:, 0], int),
    "data": np.asfarray(src[:, 2:], float),
    "names": src[:, 1]
}

# %% [markdown]
# # Prepare Data
# ## Normalise data and perform PCA
#   - Calculate the index position for each target value
#   - Normalise the  source data using sklearn.preprocessing.normalize
#   - Perform 2d PCA using sklearn.decomposition.PCA and PCA.fit_transform

# %%
from sklearn import decomposition, preprocessing

data["normalisedData"] = preprocessing.normalize(data["data"])
normalisedTarget = preprocessing.normalize([data["target"]])

pca = decomposition.PCA()
pca.fit(data["normalisedData"])
plt.plot(np.arange(1, pca.n_components_+1), pca.explained_variance_ratio_)
plt.xlabel('Number of components')
plt.ylabel('Explained variance ratio')
plt.title('Scree Plot')

PCA = decomposition.PCA(n_components=3) # "elbow" of the scree plot
projection = PCA.fit_transform(data["normalisedData"])

plt.figure()
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter(projection[:, 0], projection[:, 1], projection[:, 2], c=normalisedTarget, cmap="viridis")
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
# Out:
# []

# %% [markdown]
# # Regression
# ## The data will now be used to evaludate three regression models
#   - A Random Forest using sklearn.ensemble.RandomForestRegressor
#   - A Neural Network using sklearn.neural_network.MLPRegressor
#   - A Support Vector Machine using sklearn.svm.SVR

# %%
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error, make_scorer

from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR

X_train, X_test, y_train, y_test = train_test_split(projection, data["target"], train_size=0.75)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

def predictContainers(data, target, names, top_n, model):
    """

    :param data:
    :param target:
    :param names:
    :param top_n:
    :param model:
    :return:
    """
    predictions = np.array(model.predict(data), int)
    order = np.argsort(predictions)

    out = np.array([names[order[-top_n:]], predictions[order[-top_n:]], target[order[-top_n:]]])

    plt.figure()
    fig, ax = plt.subplots()
    figData = np.rot90(out, 1)
    fig.patch.set_visible(False)
    ax.axis('tight')
    ax.axis('off')
    table = ax.table(cellText=figData, loc='center', colLabels=("Container Ship", "Predicted Capacity", "Actual Capacity"))
    table.set_fontsize(30)
    table.scale(1.5, 1.5)

    return out

def evaluateModel(X_train, X_test, y_train, y_test, repeats, crossValidations, model):
    """

    :param X_train:
    :param X_test:
    :param y_train:
    :param y_test:
    :param repeats:
    :param crossValidations:
    :param model:
    :return:
    """
    trainAcc = []
    testAcc = []
    scorer = make_scorer(mean_squared_error)

    for X in range(repeats):
        trainAcc.append(cross_val_score(model, X_train, y_train, cv=crossValidations, scoring=scorer))
        testAcc.append(scorer(model, X_test, y_test))

    trainAccNp = np.array(trainAcc)
    plt.figure()
    plt.boxplot([trainAccNp[:, x] for x in range(crossValidations)] + [testAcc])
    plt.xlabel(" ".join([f"({x + 1}) CV-{x + 1}, " for x in range(crossValidations)]) + f"({crossValidations + 1}) test")
    plt.ylabel("Mean Squared Error (the lower the better)")

    return trainAcc, testAcc
# Out:
# (75, 3) (25, 3) (75,) (25,)

# %% [markdown]
# ## Random Forest

# %%
rfr = RandomForestRegressor()
rfr.fit(X_train, y_train)

predictContainers(projection, data["target"], data["names"], 10, rfr)
evaluateModel(X_train, X_test, y_train, y_test, 30, 5, rfr)
# Out:
# ([array([2.17002343e+10, 6.11057881e+10, 1.81271329e+10, 1.11999971e+11,
#          1.55806873e+10]),
#   array([2.24323304e+10, 5.41365063e+10, 1.93011260e+10, 1.00852072e+11,
#          1.52321858e+10]),
#   array([2.06225074e+10, 5.21731202e+10, 1.68525487e+10, 1.08030055e+11,
#          1.76556336e+10]),
#   array([1.99772115e+10, 4.92215121e+10, 1.95347258e+10, 1.09696817e+11,
#          1.50895569e+10]),
#   array([2.10465512e+10, 6.05770378e+10, 1.91427796e+10, 1.07672581e+11,
#          1.59632351e+10]),
#   array([1.92448529e+10, 5.46640524e+10, 1.80026842e+10, 1.02588231e+11,
#          1.62066373e+10]),
#   array([2.15760567e+10, 5.69294148e+10, 1.82197246e+10, 1.03939883e+11,
#          1.69089091e+10]),
#   array([1.80153894e+10, 5.30435557e+10, 1.76841191e+10, 1.07111987e+11,
#          1.45972199e+10]),
#   array([2.04429410e+10, 5.98848805e+10, 1.69073351e+10, 1.08033649e+11,
#          1.51631402e+10]),
#   array([2.18143079e+10, 5.66243359e+10, 1.77161534e+10, 1.08685584e+11,
#          1.65725068e+10]),
#   array([2.01883029e+10, 5.67469345e+10, 1.82726187e+10, 1.03790802e+11,
#          1.57701680e+10]),
#   array([2.12242678e+10, 5.88246309e+10, 1.77229602e+10, 1.01212962e+11,
#          1.51005761e+10]),
#   array([2.23882358e+10, 6.16094375e+10, 1.86700965e+10, 1.08307031e+11,
#          1.57398144e+10]),
#   array([2.13025291e+10, 6.62238361e+10, 1.80138594e+10, 1.10544333e+11,
#          1.66365496e+10]),
#   array([2.05775985e+10, 5.69629623e+10, 1.85839330e+10, 1.05743633e+11,
#          1.61877581e+10]),
#   array([2.00927610e+10, 5.33489566e+10, 1.80887667e+10, 1.10161321e+11,
#          1.70124195e+10]),
#   array([2.20305074e+10, 5.30170548e+10, 1.66841709e+10, 1.08197644e+11,
#          1.57770926e+10]),
#   array([2.06013188e+10, 6.28899372e+10, 1.70986642e+10, 1.05595918e+11,
#          1.45337763e+10]),
#   array([2.10391281e+10, 6.10073871e+10, 1.73109633e+10, 1.10273511e+11,
#          1.58615391e+10]),
#   array([2.04300529e+10, 6.18174308e+10, 1.72994938e+10, 1.14961305e+11,
#          1.68630773e+10]),
#   array([2.07924397e+10, 7.08687009e+10, 1.68815310e+10, 1.01481578e+11,
#          1.65495116e+10]),
#   array([2.04192058e+10, 5.72881350e+10, 1.90171368e+10, 1.06246930e+11,
#          1.60119980e+10]),
#   array([2.01769494e+10, 4.92149645e+10, 1.89085446e+10, 1.07332933e+11,
#          1.70066358e+10]),
#   array([1.91475391e+10, 6.39893318e+10, 1.71596766e+10, 1.11438671e+11,
#          1.47502712e+10]),
#   array([1.91651081e+10, 6.24533225e+10, 1.52577275e+10, 1.00422680e+11,
#          1.58266106e+10]),
#   array([2.06263754e+10, 4.94155216e+10, 1.66484017e+10, 1.08555178e+11,
#          1.75873634e+10]),
#   array([2.17792708e+10, 5.54807297e+10, 1.78788092e+10, 1.00604435e+11,
#          1.68305590e+10]),
#   array([2.05740494e+10, 5.38384950e+10, 1.77958441e+10, 1.15185184e+11,
#          1.66686917e+10]),
#   array([1.94657611e+10, 5.24666485e+10, 1.79038438e+10, 1.09933211e+11,
#          1.64827471e+10]),
#   array([2.06404133e+10, 6.03957363e+10, 1.94721805e+10, 1.09149745e+11,
#          1.64453658e+10])],
#  [55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602,
#   55717425809.99602])

# %% [markdown]
# ## Neural Network

# %%
mlpr = MLPRegressor(early_stopping=True, max_iter=10000, solver='lbfgs')
mlpr.fit(X_train, y_train)

predictContainers(projection, data["target"], data["names"], 10, mlpr)
evaluateModel(X_train, X_test, y_train, y_test, 30, 5, mlpr)

# %% [markdown]
# ## Support Vector Machine

# %%
svr = SVR()
svr.fit(X_train, y_train)

predictContainers(projection, data["target"], data["names"], 10, svr)
evaluateModel(X_train, X_test, y_train, y_test, 30, 5, svr)
